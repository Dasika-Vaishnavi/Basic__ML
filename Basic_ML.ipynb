# %% [markdown]
# <a href="https://colab.research.google.com/github/Dasika-Vaishnavi/Basic__ML/blob/main/Basic_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # sum of two numbers

# %%
a = int(input())
b = int(input())
print(a+b)
# Out:
# 110
# 370
# 480

# %% [markdown]
# # Percentage interest (simple)

# %%
p = int(input())  #principle
t = int(input())  #time
r = int(input())  #rate
i = (p*t*r/100)   #interest
print(i)
# Out:
# 1000
# 1
# 12
# 120.0

# %% [markdown]
# # pyramid pattern

# %%
def pypart(n):
    myList = []
    for i in range(1,n+1):
        myList.append("*"*i)
    print("\n".join(myList))
n = int(input())
pypart(n)
# Out:
# 7
# *
# **
# ***
# ****
# *****
# ******
# *******
